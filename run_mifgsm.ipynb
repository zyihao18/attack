# %%
import argparse
import os
import random

import numpy as np
import torch
import torchvision.models as models
from torchvision import transforms

from attack_utils import run_experiment
from impl_mifgsm import MIFGSM

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"使用设备: {device}")

datasets = {
    'correct_1000_AlexNet': ('alexnet', models.AlexNet_Weights.IMAGENET1K_V1),
    'correct_1000_DenseNet121': ('densenet121', models.DenseNet121_Weights.IMAGENET1K_V1),
    'correct_1000_GoogLeNet': ('googlenet', models.GoogLeNet_Weights.IMAGENET1K_V1),
    'correct_1000_MobileNetV3_large': ('mobilenet_v3_large', models.MobileNet_V3_Large_Weights.IMAGENET1K_V1),
    'correct_1000_ResNet34': ('resnet34', models.ResNet34_Weights.IMAGENET1K_V1),
    'correct_1000_VGG11': ('vgg11', models.VGG11_Weights.IMAGENET1K_V1),
    'correct_1000_EfficientNet_b0': ('efficientnet_b0', models.EfficientNet_B0_Weights.IMAGENET1K_V1),
}

config = {
    'SEED': 42,
    'selected_count': 500,
    'output_dir': 'adversarial_samples',
    'attack_name': 'mifgsm',
    'MAX_SAVE_ADV': 10,
    'if_save_adv': False,
    'threshold': 1e-6,
    'target_labels': torch.tensor([100]).to(device),
    'if_target': False,
    'if_prune': False,
    # 攻击参数
    'eps': 100/255,
    'alpha': 1/255,
    'steps': 100,
    'decay': 1.0,
    'targeted': False,
    # 剪枝参数
    'step_ratio': 0.01,
    'max_ratio': 1.0,
}

parser = argparse.ArgumentParser(description='Adversarial Attack Experiment')
parser.add_argument('--eps', type=float, default=config['eps'], help='Epsilon for MIFGSM')
parser.add_argument('--alpha', type=float, default=config['alpha'], help='Alpha for MIFGSM')
parser.add_argument('--steps', type=int, default=config['steps'], help='Steps for MIFGSM')
parser.add_argument('--decay', type=float, default=config['decay'], help='Momentum decay for MIFGSM')
args = parser.parse_args([])

config.update(vars(args))

SEED = config['SEED']
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# 使用设备: cuda

# %%
if __name__ == "__main__":
    for dataset_name, (model_name, weights) in datasets.items():
        print(f"\n=== 开始实验: {dataset_name} 使用模型 {model_name} ===")

        model = getattr(models, model_name)(weights=weights).to(device)
        model.eval()

        transform = transforms.Compose([
            transforms.Resize(256),
            transforms.ToTensor(),
        ])

        config['val_dir'] = f"./{dataset_name}"
        config['attack_name'] = f"mifgsm_{model_name}"

        val_dir = config['val_dir']
        all_images = [f for f in os.listdir(val_dir) if f.endswith('.JPEG')]
        selected_images = random.sample(all_images, min(config['selected_count'], len(all_images)))

        output_dir = config['output_dir']
        attack_name = config['attack_name']
        attack_output_dir = os.path.join(output_dir, attack_name)
        os.makedirs(attack_output_dir, exist_ok=True)

        results = run_experiment(
            config=config,
            transform=transform,
            model=model,
            device=device,
            selected_images=selected_images,
            attack_output_dir=attack_output_dir,
            attack_cls=MIFGSM,
        )

        print(f"=== 实验完成: {dataset_name} ===")
# Out:
# === 开始实验: correct_1000_AlexNet 使用模型 alexnet ===
# mifgsm_alexnet: 100%|██████████| 500/500 [00:17<00:00, 28.18it/s]
# 配置: {'SEED': 42, 'selected_count': 500, 'output_dir': 'adversarial_samples', 'attack_name': 'mifgsm_alexnet', 'MAX_SAVE_ADV': 10, 'if_save_adv': False, 'threshold': 1e-06, 'target_labels': tensor([100], device='cuda:0'), 'if_target': True, 'if_prune': False, 'eps': 0.39215686274509803, 'alpha': 0.00392156862745098, 'steps': 100, 'decay': 1.0, 'targeted': True, 'step_ratio': 0.01, 'max_ratio': 1.0, 'val_dir': './correct_1000_AlexNet'}
# 成功攻击: 500/500
# 攻击成功率: 100.00%
# 平均被修改像素点数量: 85560.70
# 平均被修改像素比例: 98.63%
# 平均扰动均值: 13495.31
# 平均 SSIM: 0.925713
# 平均 PSNR: 37.1499dB
# SSIM >= 0.975: 21.40%
# SSIM >= 0.98: 14.80%
# SSIM >= 0.985: 8.60%
# SSIM >= 0.99: 2.60%
# SSIM >= 0.995: 0.60%
# PSNR >= 39dB: 31.00%
# PSNR >= 41dB: 7.60%
# PSNR >= 43dB: 5.20%
# PSNR >= 45dB: 0.80%
# PSNR >= 47dB: 0.80%
# === 实验完成: correct_1000_AlexNet ===
#
# === 开始实验: correct_1000_DenseNet121 使用模型 densenet121 ===
# mifgsm_densenet121: 100%|██████████| 500/500 [01:00<00:00,  8.27it/s]
# 配置: {'SEED': 42, 'selected_count': 500, 'output_dir': 'adversarial_samples', 'attack_name': 'mifgsm_densenet121', 'MAX_SAVE_ADV': 10, 'if_save_adv': False, 'threshold': 1e-06, 'target_labels': tensor([100], device='cuda:0'), 'if_target': True, 'if_prune': False, 'eps': 0.39215686274509803, 'alpha': 0.00392156862745098, 'steps': 100, 'decay': 1.0, 'targeted': True, 'step_ratio': 0.01, 'max_ratio': 1.0, 'val_dir': './correct_1000_DenseNet121'}
# 成功攻击: 500/500
# 攻击成功率: 100.00%
# 平均被修改像素点数量: 84753.33
# 平均被修改像素比例: 98.39%
# 平均扰动均值: 8312.15
# 平均 SSIM: 0.966801
# 平均 PSNR: 41.0530dB
# SSIM >= 0.975: 47.40%
# SSIM >= 0.98: 36.80%
# SSIM >= 0.985: 25.00%
# SSIM >= 0.99: 14.40%
# SSIM >= 0.995: 3.20%
# PSNR >= 39dB: 80.20%
# PSNR >= 41dB: 37.80%
# PSNR >= 43dB: 37.60%
# PSNR >= 45dB: 3.80%
# PSNR >= 47dB: 3.80%
# === 实验完成: correct_1000_DenseNet121 ===
#
# === 开始实验: correct_1000_GoogLeNet 使用模型 googlenet ===
# mifgsm_googlenet: 100%|██████████| 500/500 [00:39<00:00, 12.57it/s]
# 配置: {'SEED': 42, 'selected_count': 500, 'output_dir': 'adversarial_samples', 'attack_name': 'mifgsm_googlenet', 'MAX_SAVE_ADV': 10, 'if_save_adv': False, 'threshold': 1e-06, 'target_labels': tensor([100], device='cuda:0'), 'if_target': True, 'if_prune': False, 'eps': 0.39215686274509803, 'alpha': 0.00392156862745098, 'steps': 100, 'decay': 1.0, 'targeted': True, 'step_ratio': 0.01, 'max_ratio': 1.0, 'val_dir': './correct_1000_GoogLeNet'}
# 成功攻击: 500/500
# 攻击成功率: 100.00%
# 平均被修改像素点数量: 84912.03
# 平均被修改像素比例: 98.76%
# 平均扰动均值: 10831.79
# 平均 SSIM: 0.943926
# 平均 PSNR: 38.9526dB
# SSIM >= 0.975: 29.00%
# SSIM >= 0.98: 23.00%
# SSIM >= 0.985: 15.20%
# SSIM >= 0.99: 9.00%
# SSIM >= 0.995: 2.20%
# PSNR >= 39dB: 49.60%
# PSNR >= 41dB: 18.40%
# PSNR >= 43dB: 18.40%
# PSNR >= 45dB: 2.00%
# PSNR >= 47dB: 2.00%
# === 实验完成: correct_1000_GoogLeNet ===
#
# === 开始实验: correct_1000_MobileNetV3_large 使用模型 mobilenet_v3_large ===
# mifgsm_mobilenet_v3_large: 100%|██████████| 500/500 [00:33<00:00, 15.06it/s]
# 配置: {'SEED': 42, 'selected_count': 500, 'output_dir': 'adversarial_samples', 'attack_name': 'mifgsm_mobilenet_v3_large', 'MAX_SAVE_ADV': 10, 'if_save_adv': False, 'threshold': 1e-06, 'target_labels': tensor([100], device='cuda:0'), 'if_target': True, 'if_prune': False, 'eps': 0.39215686274509803, 'alpha': 0.00392156862745098, 'steps': 100, 'decay': 1.0, 'targeted': True, 'step_ratio': 0.01, 'max_ratio': 1.0, 'val_dir': './correct_1000_MobileNetV3_large'}
# 成功攻击: 500/500
# 攻击成功率: 100.00%
# 平均被修改像素点数量: 83427.88
# 平均被修改像素比例: 96.75%
# 平均扰动均值: 8553.75
# 平均 SSIM: 0.965966
# 平均 PSNR: 40.8205dB
# SSIM >= 0.975: 45.80%
# SSIM >= 0.98: 34.80%
# SSIM >= 0.985: 26.80%
# SSIM >= 0.99: 14.40%
# SSIM >= 0.995: 2.80%
# PSNR >= 39dB: 77.60%
# PSNR >= 41dB: 37.60%
# PSNR >= 43dB: 33.80%
# PSNR >= 45dB: 2.60%
# PSNR >= 47dB: 2.60%
# === 实验完成: correct_1000_MobileNetV3_large ===
#
# === 开始实验: correct_1000_ResNet34 使用模型 resnet34 ===
# mifgsm_resnet34: 100%|██████████| 500/500 [00:24<00:00, 20.11it/s]
# 配置: {'SEED': 42, 'selected_count': 500, 'output_dir': 'adversarial_samples', 'attack_name': 'mifgsm_resnet34', 'MAX_SAVE_ADV': 10, 'if_save_adv': False, 'threshold': 1e-06, 'target_labels': tensor([100], device='cuda:0'), 'if_target': True, 'if_prune': False, 'eps': 0.39215686274509803, 'alpha': 0.00392156862745098, 'steps': 100, 'decay': 1.0, 'targeted': True, 'step_ratio': 0.01, 'max_ratio': 1.0, 'val_dir': './correct_1000_ResNet34'}
# 成功攻击: 500/500
# 攻击成功率: 100.00%
# 平均被修改像素点数量: 84795.66
# 平均被修改像素比例: 97.80%
# 平均扰动均值: 8256.43
# 平均 SSIM: 0.966932
# 平均 PSNR: 41.2179dB
# SSIM >= 0.975: 48.40%
# SSIM >= 0.98: 38.80%
# SSIM >= 0.985: 27.40%
# SSIM >= 0.99: 14.60%
# SSIM >= 0.995: 4.80%
# PSNR >= 39dB: 80.60%
# PSNR >= 41dB: 42.60%
# PSNR >= 43dB: 42.40%
# PSNR >= 45dB: 5.80%
# PSNR >= 47dB: 5.80%
# === 实验完成: correct_1000_ResNet34 ===
#
# === 开始实验: correct_1000_VGG11 使用模型 vgg11 ===
# mifgsm_vgg11: 100%|██████████| 500/500 [00:34<00:00, 14.31it/s]
# 配置: {'SEED': 42, 'selected_count': 500, 'output_dir': 'adversarial_samples', 'attack_name': 'mifgsm_vgg11', 'MAX_SAVE_ADV': 10, 'if_save_adv': False, 'threshold': 1e-06, 'target_labels': tensor([100], device='cuda:0'), 'if_target': True, 'if_prune': False, 'eps': 0.39215686274509803, 'alpha': 0.00392156862745098, 'steps': 100, 'decay': 1.0, 'targeted': True, 'step_ratio': 0.01, 'max_ratio': 1.0, 'val_dir': './correct_1000_VGG11'}
# 成功攻击: 500/500
# 攻击成功率: 100.00%
# 平均被修改像素点数量: 84843.65
# 平均被修改像素比例: 98.50%
# 平均扰动均值: 9260.96
# 平均 SSIM: 0.957331
# 平均 PSNR: 40.4169dB
# SSIM >= 0.975: 40.60%
# SSIM >= 0.98: 31.00%
# SSIM >= 0.985: 22.40%
# SSIM >= 0.99: 15.00%
# SSIM >= 0.995: 4.20%
# PSNR >= 39dB: 68.40%
# PSNR >= 41dB: 37.00%
# PSNR >= 43dB: 32.80%
# PSNR >= 45dB: 5.40%
# PSNR >= 47dB: 5.40%
# === 实验完成: correct_1000_VGG11 ===
#
# === 开始实验: correct_1000_EfficientNet_b0 使用模型 efficientnet_b0 ===
# mifgsm_efficientnet_b0: 100%|██████████| 500/500 [00:47<00:00, 10.48it/s]
# 配置: {'SEED': 42, 'selected_count': 500, 'output_dir': 'adversarial_samples', 'attack_name': 'mifgsm_efficientnet_b0', 'MAX_SAVE_ADV': 10, 'if_save_adv': False, 'threshold': 1e-06, 'target_labels': tensor([100], device='cuda:0'), 'if_target': True, 'if_prune': False, 'eps': 0.39215686274509803, 'alpha': 0.00392156862745098, 'steps': 100, 'decay': 1.0, 'targeted': True, 'step_ratio': 0.01, 'max_ratio': 1.0, 'val_dir': './correct_1000_EfficientNet_b0'}
# 成功攻击: 500/500
# 攻击成功率: 100.00%
# 平均被修改像素点数量: 85534.21
# 平均被修改像素比例: 98.64%
# 平均扰动均值: 13974.38
# 平均 SSIM: 0.918167
# 平均 PSNR: 36.7507dB
# SSIM >= 0.975: 17.00%
# SSIM >= 0.98: 13.20%
# SSIM >= 0.985: 7.20%
# SSIM >= 0.99: 2.80%
# SSIM >= 0.995: 0.80%
# PSNR >= 39dB: 23.00%
# PSNR >= 41dB: 9.20%
# PSNR >= 43dB: 5.20%
# PSNR >= 45dB: 0.60%
# PSNR >= 47dB: 0.60%
# === 实验完成: correct_1000_EfficientNet_b0 ===
